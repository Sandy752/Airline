# %% [markdown]
# **Importing Libraries**

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Database Connection**

# %%
connection=sqlite3.connect('travels.sqlite')
cursor=connection.cursor()

# %% [markdown]
# **EDA**

# %%
cursor.execute('''select name from sqlite_master where type ="table";''')
print('List of the table Present in the table: ')
table_list=[table[0] for table in cursor.fetchall()]
table_list
# Out:
# List of the table Present in the table:
# ['aircrafts_data',
#  'airports_data',
#  'boarding_passes',
#  'bookings',
#  'flights',
#  'seats',
#  'ticket_flights',
#  'tickets']

# %%
for table in table_list:
    print('\n',table)
    column_info=connection.execute('PRAGMA table_info({})'.format(table))
    for column in column_info.fetchall():
        print(column[1:3])
# Out:
#  aircrafts_data
# ('aircraft_code', 'character(3)')
# ('model', 'jsonb')
# ('range', 'INTEGER')
#
#  airports_data
# ('airport_code', 'character(3)')
# ('airport_name', 'jsonb')
# ('city', 'jsonb')
# ('coordinates', 'point')
# ('timezone', 'TEXT')
#
#  boarding_passes
# ('ticket_no', 'character(13)')
# ('flight_id', 'INTEGER')
# ('boarding_no', 'INTEGER')
# ('seat_no', 'character varying(4)')
#
#  bookings
# ('book_ref', 'character(6)')
# ('book_date', 'timestamp with time zone')
# ('total_amount', 'numeric(10,2)')
#
#  flights
# ('flight_id', 'INTEGER')
# ('flight_no', 'character(6)')
# ('scheduled_departure', 'timestamp with time zone')
# ('scheduled_arrival', 'timestamp with time zone')
# ('departure_airport', 'character(3)')
# ('arrival_airport', 'character(3)')
# ('status', 'character varying(20)')
# ('aircraft_code', 'character(3)')
# ('actual_departure', 'timestamp with time zone')
# ('actual_arrival', 'timestamp with time zone')
#
#  seats
# ('aircraft_code', 'character(3)')
# ...

# %% [markdown]
# ***Checking for null Values***

# %%
for table in table_list:
    print('\ntable:', table)
    df_table=pd.read_sql_query(f'select * from {table}',connection)
    print(df_table.isnull().sum())
# Out:
# table: aircrafts_data
# aircraft_code    0
# model            0
# range            0
# dtype: int64
#
# table: airports_data
# airport_code    0
# airport_name    0
# city            0
# coordinates     0
# timezone        0
# dtype: int64
#
# table: boarding_passes
# ticket_no      0
# flight_id      0
# boarding_no    0
# seat_no        0
# dtype: int64
#
# table: bookings
# book_ref        0
# book_date       0
# total_amount    0
# dtype: int64
#
# table: flights
# flight_id              0
# flight_no              0
# scheduled_departure    0
# scheduled_arrival      0
# departure_airport      0
# arrival_airport        0
# status                 0
# aircraft_code          0
# actual_departure       0
# actual_arrival         0
# dtype: int64
#
# table: seats
# aircraft_code      0
# seat_no            0
# fare_conditions    0
# dtype: int64
#
# table: ticket_flights
# ticket_no          0
# flight_id          0
# fare_conditions    0
# amount             0
# dtype: int64
#
# ...

# %%
def table(table_name):
        query = f'SELECT * FROM {table_name};'
        table_data = pd.read_sql_query(query, connection)
        print(table_data.shape)
        return table_data

# %%
table('aircrafts_data')
# Out:
# (9, 3)
#   aircraft_code                                              model  range
# 0           773    {"en": "Boeing 777-300", "ru": "Боинг 777-300"}  11100
# 1           763    {"en": "Boeing 767-300", "ru": "Боинг 767-300"}   7900
# 2           SU9  {"en": "Sukhoi Superjet-100", "ru": "Сухой Суп...   3000
# 3           320  {"en": "Airbus A320-200", "ru": "Аэробус A320-...   5700
# 4           321  {"en": "Airbus A321-200", "ru": "Аэробус A321-...   5600
# 5           319  {"en": "Airbus A319-100", "ru": "Аэробус A319-...   6700
# 6           733    {"en": "Boeing 737-300", "ru": "Боинг 737-300"}   4200
# 7           CN1  {"en": "Cessna 208 Caravan", "ru": "Сессна 208...   1200
# 8           CR2  {"en": "Bombardier CRJ-200", "ru": "Бомбардье ...   2700

# %%
table('airports_data')
# Out:
# (104, 5)
#     airport_code                                       airport_name  \
# 0            YKS          {"en": "Yakutsk Airport", "ru": "Якутск"}
# 1            MJZ            {"en": "Mirny Airport", "ru": "Мирный"}
# 2            KHV  {"en": "Khabarovsk-Novy Airport", "ru": "Хабар...
# 3            PKC        {"en": "Yelizovo Airport", "ru": "Елизово"}
# 4            UUS  {"en": "Yuzhno-Sakhalinsk Airport", "ru": "Хом...
# ..           ...                                                ...
# 99           MMK       {"en": "Murmansk Airport", "ru": "Мурманск"}
# 100          ABA           {"en": "Abakan Airport", "ru": "Абакан"}
# 101          BAX         {"en": "Barnaul Airport", "ru": "Барнаул"}
# 102          AAQ  {"en": "Anapa Vityazevo Airport", "ru": "Витяз...
# 103          CNN         {"en": "Chulman Airport", "ru": "Чульман"}
#
#                                                   city  \
# 0                    {"en": "Yakutsk", "ru": "Якутск"}
# ...

# %%
table('boarding_passes')
# Out:
# (579686, 4)
#             ticket_no  flight_id  boarding_no seat_no
# 0       0005435212351      30625            1      2D
# 1       0005435212386      30625            2      3G
# 2       0005435212381      30625            3      4H
# 3       0005432211370      30625            4      5D
# 4       0005435212357      30625            5     11A
# ...               ...        ...          ...     ...
# 579681  0005434302871      19945           85     20F
# 579682  0005432892791      19945           86     21C
# 579683  0005434302869      19945           87     20E
# 579684  0005432802476      19945           88     21F
# 579685  0005432802482      19945           89     21E
#
# [579686 rows x 4 columns]

# %%
table('bookings')
# Out:
# (262788, 3)
#        book_ref               book_date  total_amount
# 0        00000F  2017-07-05 03:12:00+03        265700
# 1        000012  2017-07-14 09:02:00+03         37900
# 2        000068  2017-08-15 14:27:00+03         18100
# 3        000181  2017-08-10 13:28:00+03        131800
# 4        0002D8  2017-08-07 21:40:00+03         23600
# ...         ...                     ...           ...
# 262783   FFFEF3  2017-07-17 07:23:00+03         56000
# 262784   FFFF2C  2017-08-08 05:55:00+03         10800
# 262785   FFFF43  2017-07-20 20:42:00+03         78500
# 262786   FFFFA8  2017-08-08 04:45:00+03         28800
# 262787   FFFFF7  2017-07-01 22:12:00+03         73600
#
# [262788 rows x 3 columns]

# %%
table('flights')
# Out:
# (33121, 10)
#        flight_id flight_no     scheduled_departure       scheduled_arrival  \
# 0           1185    PG0134  2017-09-10 09:50:00+03  2017-09-10 14:55:00+03
# 1           3979    PG0052  2017-08-25 14:50:00+03  2017-08-25 17:35:00+03
# 2           4739    PG0561  2017-09-05 12:30:00+03  2017-09-05 14:15:00+03
# 3           5502    PG0529  2017-09-12 09:50:00+03  2017-09-12 11:20:00+03
# 4           6938    PG0461  2017-09-04 12:25:00+03  2017-09-04 13:20:00+03
# ...          ...       ...                     ...                     ...
# 33116      33117    PG0063  2017-08-02 19:25:00+03  2017-08-02 20:10:00+03
# 33117      33118    PG0063  2017-07-28 19:25:00+03  2017-07-28 20:10:00+03
# 33118      33119    PG0063  2017-09-08 19:25:00+03  2017-09-08 20:10:00+03
# 33119      33120    PG0063  2017-08-01 19:25:00+03  2017-08-01 20:10:00+03
# 33120      33121    PG0063  2017-08-26 19:25:00+03  2017-08-26 20:10:00+03
#
# ...

# %%
table('seats')
# Out:
# (1339, 3)
#      aircraft_code seat_no fare_conditions
# 0              319      2A        Business
# 1              319      2C        Business
# 2              319      2D        Business
# 3              319      2F        Business
# 4              319      3A        Business
# ...            ...     ...             ...
# 1334           773     48H         Economy
# 1335           773     48K         Economy
# 1336           773     49A         Economy
# 1337           773     49C         Economy
# 1338           773     49D         Economy
#
# [1339 rows x 3 columns]

# %%
table('ticket_flights')
# Out:
# (1045726, 4)
#              ticket_no  flight_id fare_conditions  amount
# 0        0005432159776      30625        Business   42100
# 1        0005435212351      30625        Business   42100
# 2        0005435212386      30625        Business   42100
# 3        0005435212381      30625        Business   42100
# 4        0005432211370      30625        Business   42100
# ...                ...        ...             ...     ...
# 1045721  0005435097522      32094         Economy    5200
# 1045722  0005435097521      32094         Economy    5200
# 1045723  0005435104384      32094         Economy    5200
# 1045724  0005435104352      32094         Economy    5200
# 1045725  0005435104389      32094         Economy    5200
#
# [1045726 rows x 4 columns]

# %%
table('tickets')
# Out:
# (366733, 3)
#             ticket_no book_ref passenger_id
# 0       0005432000987   06B046  8149 604011
# 1       0005432000988   06B046  8499 420203
# 2       0005432000989   E170C3  1011 752484
# 3       0005432000990   E170C3  4849 400049
# 4       0005432000991   F313DD  6615 976589
# ...               ...      ...          ...
# 366728  0005435999869   D730BA  0474 690760
# 366729  0005435999870   D730BA  6535 751108
# 366730  0005435999871   A1AD46  1596 156448
# 366731  0005435999872   7B6A53  9374 822707
# 366732  0005435999873   7B6A53  7380 075822
#
# [366733 rows x 3 columns]

# %% [markdown]
# ## Basic Analysis

# %% [markdown]
# **How many plane have more than 100 seats**

# %%
pd.read_sql_query('''select aircraft_code,count(*) as num_of_seat from seats group by aircraft_code 
                    having num_of_seat>100 order by count(*) desc''', connection)
# Out:
#   aircraft_code  num_of_seat
# 0           773          402
# 1           763          222
# 2           321          170
# 3           320          140
# 4           733          130
# 5           319          116

# %% [markdown]
# **How the number of tickets booked and total amount earned changed with the time**

# %%
ticket=pd.read_sql('''
          select * from tickets as t inner join bookings as b
          on t.book_ref=b.book_ref
          ''',connection)

# %%
ticket['book_date']=pd.to_datetime(ticket['book_date'])
ticket['date']=ticket['book_date'].dt.date
x=ticket.groupby('date')[['date']].count()
plt.figure(figsize=(18,6))
plt.plot(x.index,x['date'],marker='o', color='teal')
plt.xlabel('Date', fontsize=20)
plt.ylabel('Numbers of tickets', fontsize=20)
plt.grid(color='black')
plt.show()

# %%
ticket.groupby('date')[['date']].count().head()
# Out:
#             date
# date
# 2017-06-21     6
# 2017-06-22    12
# 2017-06-23    28
# 2017-06-24   106
# 2017-06-25   266

# %%
booking=pd.read_sql_query('''
    select * from bookings
                          ''',connection)
booking['book_date']=pd.to_datetime(booking['book_date'])
booking['date']=booking['book_date'].dt.date
x=booking.groupby('date')[['date']].count()
plt.figure(figsize=(18,6))
plt.plot(x.index,x['date'],marker='o', color='teal')
plt.xlabel('Date', fontsize=20)
plt.ylabel('Number of Booking',fontsize=20)
plt.grid(color='black')
plt.show()

# %%
booking.groupby('date')[['date']].count().head()
# Out:
#             date
# date
# 2017-06-21     3
# 2017-06-22     7
# 2017-06-23    20
# 2017-06-24    74
# 2017-06-25   191

# %% [markdown]
# **Calculate the average charges for each aircraft with different fare condition**

# %%
df=pd.read_sql_query('''
                  select fare_conditions,aircraft_code,avg(amount)
                  from ticket_flights as t join flights as f
                  on t.flight_id=f.flight_id
                  group by aircraft_code, fare_conditions
                  ''',connection)

# %%
sns.barplot(data=df,x='aircraft_code',y='avg(amount)',hue='fare_conditions')
# Out:
# <Axes: xlabel='aircraft_code', ylabel='avg(amount)'>

# %% [markdown]
# ### Analyzing Occupancy Rate

# %% [markdown]
# **For each aircraft, calculate the total revenue per year and the average revenue per ticket.**

# %%
pd.read_sql_query("""select aircraft_code, ticket_count, total_revenue, 
                  total_revenue/ticket_count as avg_revenue_per_ticket 
                  from 
                  (select aircraft_code, count(*) as ticket_count, sum(amount) as total_revenue from ticket_flights 
                  join flights on ticket_flights.flight_id=flights.flight_id group by aircraft_code)""", connection)
# Out:
#   aircraft_code  ticket_count  total_revenue  avg_revenue_per_ticket
# 0           319         52853     2706163100                   51201
# 1           321        107129     1638164100                   15291
# 2           733         86102     1426552100                   16568
# 3           763        124774     4371277100                   35033
# 4           773        144376     3431205500                   23765
# 5           CN1         14672       96373800                    6568
# 6           CR2        150122     1982760500                   13207
# 7           SU9        365698     5114484700                   13985

# %% [markdown]
# **Calculate the average occupancy per aircraft.**

# %%
occupancy_rate=pd.read_sql_query("""select a.aircraft_code,avg(a.seats_count) as booked_seats, 
                  b.num_seats,round(avg(a.seats_count)/b.num_seats,2) as occupancy_rate
                  from
                  (select aircraft_code, flights.flight_id, count(*) as seats_count from boarding_passes 
                  inner join flights on boarding_passes.flight_id=flights.flight_id group by aircraft_code, 
                  flights.flight_id) as a Inner join 
                  (select aircraft_code, count(*) as num_seats from seats group by aircraft_code) as b 
                  on a.aircraft_code=b.aircraft_code group by a.aircraft_code""", connection)

occupancy_rate
# Out:
#   aircraft_code  booked_seats  num_seats  occupancy_rate
# 0           319     53.583181        116            0.46
# 1           321     88.809231        170            0.52
# 2           733     80.255462        130            0.62
# 3           763    113.937294        222            0.51
# 4           773    264.925806        402            0.66
# 5           CN1      6.004431         12            0.50
# 6           CR2     21.482847         50            0.43
# 7           SU9     56.812113         97            0.59

# %% [markdown]
# **Calculate by how much the total annual turnover could increase by giving all aircraft a 10% higher occupancy rate.**

# %%
occupancy_rate['increased_occupancy']=occupancy_rate['occupancy_rate']*.1+occupancy_rate['occupancy_rate']
occupancy_rate
# Out:
#   aircraft_code  booked_seats  num_seats  occupancy_rate  increased_occupancy
# 0           319     53.583181        116            0.46                0.506
# 1           321     88.809231        170            0.52                0.572
# 2           733     80.255462        130            0.62                0.682
# 3           763    113.937294        222            0.51                0.561
# 4           773    264.925806        402            0.66                0.726
# 5           CN1      6.004431         12            0.50                0.550
# 6           CR2     21.482847         50            0.43                0.473
# 7           SU9     56.812113         97            0.59                0.649

# %%
total_revenue=pd.read_sql_query('''select aircraft_code,sum(amount) as total_revenue from ticket_flights
                  join flights on ticket_flights.flight_id=flights.flight_id
                  group by aircraft_code
                  ''',connection)

occupancy_rate['Inc Total Annual Turnover']=(total_revenue['total_revenue']/occupancy_rate['occupancy_rate'])*occupancy_rate['increased_occupancy']
occupancy_rate
# Out:
#   aircraft_code  booked_seats  num_seats  occupancy_rate  increased_occupancy  \
# 0           319     53.583181        116            0.46                0.506
# 1           321     88.809231        170            0.52                0.572
# 2           733     80.255462        130            0.62                0.682
# 3           763    113.937294        222            0.51                0.561
# 4           773    264.925806        402            0.66                0.726
# 5           CN1      6.004431         12            0.50                0.550
# 6           CR2     21.482847         50            0.43                0.473
# 7           SU9     56.812113         97            0.59                0.649
#
#    Inc Total Annual Turnover
# 0               2.976779e+09
# 1               1.801981e+09
# 2               1.569207e+09
# 3               4.808405e+09
# 4               3.774326e+09
# 5               1.060112e+08
# 6               2.181037e+09
# ...
